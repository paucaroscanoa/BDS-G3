# %%
# !pip install yahoo-finance
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 2.6 MB/s eta 0:00:00
# ...
#   Created wheel for yahoo-finance: filename=yahoo_finance-1.4.0-py3-none-any.whl size=7218 sha256=fa555b838e50465675ba01226641de8dccfd7718e3bedc582feacbb3eaa0e2d3
#   Stored in directory: /root/.cache/pip/wheels/f6/a9/34/f1aaa343d0861148f79a9df08f380e4dbbdbe27b7ba1e0e84c
# Successfully built yahoo-finance
# ...

# %%
from yahoo_finance import stock as si
import numpy as
import matplotlib.pyplot as plt
import pandas as pd

data=si.get_data()
