# %% [markdown]
# # REGRESIÓN LINEAL SIMPLE PARA DATASET DE PENGUINS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
penguins_df = sns.load_dataset('penguins')
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# ## ELIMINAMOS NULOS

# %%
penguins_df.dropna(inplace=True)
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# ## CORRELACIÓN DE VARIABLES

# %%
sns.clustermap(
    data=penguins_df.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={'shrink':0.5},
    annot=True
)

# %% [markdown]
# ## REGRESIÓN LINEAL ENTRE FLIPPER_LENGTH_MM Y BODY_MASS_G

# %%
sns.scatterplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
import scipy

# %%
penguins_res = scipy.stats.linregress(x=penguins_df.flipper_length_mm,y=penguins_df.body_mass_g)
penguins_res
# Out:
# LinregressResult(slope=50.15326594224109, intercept=-5872.092682842817, rvalue=0.8729788985653607, pvalue=3.1328362509741374e-105, stderr=1.5402309838246375, intercept_stderr=310.2851553513504)

# %% [markdown]
# ## GRAFICAMOS LA REGRESIÓN LINEAL SIMPLE

# %%
sns.scatterplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g'
)

m = penguins_res.slope
b = penguins_res.intercept

fx_1 = np.array([penguins_df.flipper_length_mm.min(),penguins_df.flipper_length_mm.max()])
fy_1 = m * fx_1 + b

plt.plot(fx_1,fy_1,color='red')

# %% [markdown]
# ## OTRA FORMA DE GRAFICAR CON SEABORN

# %%
sns.lmplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g',
    height=10
)
