# %% [markdown]
# # Primeros pasos con Python

# %%
print('hola mundo con colab')
# Out:
# hola mundo con colab

# %% [markdown]
# # Operaciones Matemáticas

# %%
suma=4+7
print(suma)
resta=10-4
print(resta)
potencia=2**3
print(potencia)
# Out:
# 11
# 6
# 8

# %% [markdown]
# # Listas y Bucles

# %%
list_num=[1,2,3,4,5,6,8,9,14,16]
for num in list_num:
  print(num)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 8
# 9
# 14
# 16

# %% [markdown]
# # Funciones

# %%
def suma(a,b):
  return a+b

suma(2,3)
print(suma)
# Out:
# <function suma at 0x0000026B534BB560>
