# %% [markdown]
# ## Arboles de Decisión - Parámetros

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %% [markdown]
# # EDA

# %%
titanic_df.dtypes.value_counts()
# Out:
# object      5
# int64       4
# float64     2
# bool        2
# category    1
# category    1
# dtype: int64

# %%
titanic_df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
columns_to_drop = ['fare','embarked','class','who','adult_male','deck','embark_town','alive','alone']
titanic_df.drop(columns_to_drop,axis='columns',inplace=True)
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch
# 0           0       3    male  22.0      1      0
# 1           1       1  female  38.0      1      0
# 2           1       3  female  26.0      0      0
# 3           1       1  female  35.0      1      0
# 4           0       3    male  35.0      0      0
# ..        ...     ...     ...   ...    ...    ...
# 886         0       2    male  27.0      0      0
# 887         1       1  female  19.0      0      0
# 888         0       3  female   NaN      1      2
# 889         1       1    male  26.0      0      0
# 890         0       3    male  32.0      0      0
#
# [891 rows x 6 columns]

# %%
titanic_df.shape
# Out:
# (891, 6)

# %%
titanic_df.dropna()
# Out:
#      survived  pclass     sex   age  sibsp  parch
# 0           0       3    male  22.0      1      0
# 1           1       1  female  38.0      1      0
# 2           1       3  female  26.0      0      0
# 3           1       1  female  35.0      1      0
# 4           0       3    male  35.0      0      0
# ..        ...     ...     ...   ...    ...    ...
# 885         0       3  female  39.0      0      5
# 886         0       2    male  27.0      0      0
# 887         1       1  female  19.0      0      0
# 889         1       1    male  26.0      0      0
# 890         0       3    male  32.0      0      0
#
# [714 rows x 6 columns]

# %%
titanic_df.isna().sum()
# Out:
# survived      0
# pclass        0
# age         177
# sibsp         0
# parch         0
# sex           0
# dtype: int64

# %%
#Paso2: Ejecutamos pandas Missing extensión notebook
# %run "D:\Conocimiento Adquiridos\Data Science _ Codigo Bootcamp\Desarrollo_MP\BDS-G3\Dia_4\pandas_missing_extension.ipynb"

# Aplicamos la función recursiva
titanic_df = imputar_recursivo(titanic_df.copy())

print("\nDataFrame resultante:")
display(titanic_df.head(5))
display(titanic_df.missing.number_missing())
display(titanic_df.missing.missing_variable_plot())
# Out:
# Imputando en columna 'age' con promedio 29.69911764705882
#
# DataFrame resultante:
#    survived  pclass   age  sibsp  parch  sex
# 0         0       3  22.0      1      0    1
# 1         1       1  38.0      1      0    0
# 2         1       3  26.0      0      0    0
# 3         1       1  35.0      1      0    0
# 4         0       3  35.0      0      0    1
# 0
# None

# %% [markdown]
# ## CODIFICACIÓN DE VARIABLES CATEGORICAS

# %%
titanic_df.dtypes
# Out:
# survived      int64
# pclass        int64
# age         float64
# sibsp         int64
# parch         int64
# sex           int32
# dtype: object

# %%
titanic_df = pd.get_dummies(titanic_df,columns=['sex'],drop_first=True)
titanic_df.head()
# Out:
#    survived  pclass   age  sibsp  parch  sex_1
# 0         0       3  22.0      1      0      1
# 1         1       1  38.0      1      0      0
# 2         1       3  26.0      0      0      0
# 3         1       1  35.0      1      0      0
# 4         0       3  35.0      0      0      1

# %%
titanic_df['sex_1'] = titanic_df['sex_1'].astype(int)
titanic_df.rename(columns = {'sex_1':'sex'},inplace=True)
titanic_df.head(10)
# Out:
#    survived  pclass        age  sibsp  parch  sex
# 0         0       3  22.000000      1      0    1
# 1         1       1  38.000000      1      0    0
# 2         1       3  26.000000      0      0    0
# 3         1       1  35.000000      1      0    0
# 4         0       3  35.000000      0      0    1
# 5         0       3  29.699118      0      0    1
# 6         0       1  54.000000      0      0    1
# 7         0       3   2.000000      3      1    1
# 8         1       3  27.000000      0      2    0
# 9         1       2  14.000000      1      0    0

# %% [markdown]
# # PREPARACIÓN DE DATOS PARA EL ENTRENAMIENTO

# %%
from sklearn.model_selection import train_test_split
X = titanic_df.drop("survived",axis=1)
y = titanic_df['survived']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=00000)

# %% [markdown]
# ## PARAMETROS PARA ENTRENAMIENTO DE ARBOL DE DECISIÓN

# %% [markdown]
# ## SIN PARAMETROS

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree
import graphviz

tree1 = DecisionTreeClassifier()
tree1.fit(X_train,y_train)
y_pred = tree1.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy TREE 1 : {accuracy}')

#graficando el árbol
#tree.plot_tree(tree1)

dot_data = tree.export_graphviz(tree1.fit(X_train,y_train), out_file=None, 
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# Accuracy TREE 1 : 0.7932960893854749

# %% [markdown]
# ## 1. Profundidad del árbol (max_depth)

# %% [markdown]
# Controla cuán profundo puede crecer el árbol. Un árbol muy profundo puede sobreajustarse a los datos de entrenamiento, mientras que un árbol muy poco profundo puede ser subajustado.

# %%
tree2 = DecisionTreeClassifier(max_depth=3)
tree2.fit(X_train,y_train)
y_pred = tree2.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy TREE 2 : {accuracy}')

#graficando el árbol
#tree.plot_tree(tree2)
dot_data = tree.export_graphviz(tree2.fit(X_train,y_train), out_file=None, 
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# Accuracy TREE 2 : 0.8100558659217877

# %% [markdown]
# ## 2. Número mínimo de muestras por división (min_samples_split)

# %% [markdown]
# Determina el número mínimo de muestras que debe tener un nodo antes de dividirse. Un valor más alto reduce el sobreajuste.

# %%
tree3 = DecisionTreeClassifier(min_samples_split=10)
tree3.fit(X_train,y_train)
y_pred = tree3.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy TREE 3 : {accuracy}')

#graficando el árbol
#tree.plot_tree(tree3)

dot_data = tree.export_graphviz(tree3.fit(X_train,y_train), out_file=None, 
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# Accuracy TREE 3 : 0.8379888268156425

# %% [markdown]
# ## 3. Número mínimo de muestras por hoja (min_samples_leaf)

# %% [markdown]
# Define el número mínimo de muestras que puede tener una hoja. Un valor más alto evita que el árbol aprenda patrones muy específicos (ruido).

# %%
tree4 = DecisionTreeClassifier(min_samples_leaf=4)
tree4.fit(X_train,y_train)
y_pred = tree4.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy TREE 4 : {accuracy}')

#graficando el árbol
#tree.plot_tree(tree4)
dot_data = tree.export_graphviz(tree4.fit(X_train,y_train), out_file=None, 
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# Accuracy TREE 4 : 0.8324022346368715

# %% [markdown]
# ## 4. Criterio de división (criterion)

# %% [markdown]
# * gini (por defecto): mide la impureza de Gini(es una medida utilizada en los árboles de decisión para evaluar la calidad de una partición de datos en los nodos).
# * entropy: usa la ganancia de información para las divisiones.

# %%
tree5 = DecisionTreeClassifier(criterion='entropy')
tree5.fit(X_train,y_train)
y_pred = tree5.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy TREE 5 : {accuracy}')

#graficando el árbol
#tree.plot_tree(tree5)
dot_data = tree.export_graphviz(tree5.fit(X_train,y_train), out_file=None, 
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# Accuracy TREE 5 : 0.7821229050279329

# %% [markdown]
# # EVALUANDO LA MEJOR COMBINACIÓN DE PARAMETROS

# %%
from sklearn.model_selection import GridSearchCV

# definirmos varios parametros
param_grid = {
    'max_depth': [3,4,10],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4],
    'criterion':['gini','entropy']
}

clf = DecisionTreeClassifier(random_state=42)

grid_search = GridSearchCV(clf,param_grid,cv=5,scoring='accuracy',n_jobs=-1)
grid_search.fit(X_train,y_train)

print("Mejores parametros : ",grid_search.best_params_)
# Out:
# Mejores parametros :  {'criterion': 'entropy', 'max_depth': 4, 'min_samples_leaf': 4, 'min_samples_split': 2}

# %% [markdown]
# # ENTRENAMIENTO DEL MODELO CON LOS MEJORES PARAMETROS

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy best model : {accuracy}')

#graficando el árbol
#tree.plot_tree(best_model)

dot_data = tree.export_graphviz(best_model, out_file=None, 
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph
# Out:
# Accuracy best model : 0.8268156424581006

# %% [markdown]
# # VERIFICAR LA VARIABLE MAS IMPORTANTE

# %%
importances = best_model.feature_importances_
importances
# Out:
# array([0.20540776, 0.14849806, 0.10262992, 0.00953136, 0.5339329 ])

# %%
columns = X.columns
columns
# Out:
# Index(['pclass', 'age', 'sibsp', 'parch', 'sex'], dtype='object')

# %%
sns.barplot(x=columns,y=importances,palette='bright',saturation= 2.0,edgecolor='black',linewidth=2)
plt.title('Importancia de cada variable')
plt.show()
# Out:
# <ipython-input-26-252b376f9a70>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=columns,y=importances,palette='bright',saturation= 2.0,edgecolor='black',linewidth=2)
