# %%
pip install jupyter
# Out:
# Requirement already satisfied: jupyter in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (1.1.1)
# Requirement already satisfied: nbconvert in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter) (7.16.5)
# Requirement already satisfied: ipykernel in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: jupyter-console in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: ipywidgets in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter) (8.1.5)
# Requirement already satisfied: notebook in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter) (7.3.2)
# Requirement already satisfied: jupyterlab in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter) (4.3.4)
# Requirement already satisfied: nest-asyncio in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: debugpy>=1.6.5 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (1.8.12)
# Requirement already satisfied: pyzmq>=24 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: psutil in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (6.1.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: tornado>=6.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (6.4.2)
# Requirement already satisfied: comm>=0.1.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: packaging in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (24.2)
# Requirement already satisfied: traitlets>=5.4.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: ipython>=7.23.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipykernel->jupyter) (8.31.0)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipywidgets->jupyter) (3.0.13)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipywidgets->jupyter) (4.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-console->jupyter) (3.0.50)
# Requirement already satisfied: pygments in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-console->jupyter) (2.19.1)
# Requirement already satisfied: setuptools>=40.8.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab->jupyter) (65.5.0)
# Requirement already satisfied: async-lru>=1.0.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab->jupyter) (2.2.5)
# Requirement already satisfied: jinja2>=3.0.3 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab->jupyter) (3.1.5)
# Requirement already satisfied: tomli>=1.2.2 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab->jupyter) (2.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab->jupyter) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: httpx>=0.25.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: bleach[css]!=5.0.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: beautifulsoup4 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbconvert->jupyter) (3.1.0)
# Requirement already satisfied: jupyterlab-pygments in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: nbformat>=5.7 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: nbclient>=0.5.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: defusedxml in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: markupsafe>=2.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from async-lru>=1.0.0->jupyterlab->jupyter) (4.12.2)
# Requirement already satisfied: webencodings in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: httpcore==1.* in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.7)
# Requirement already satisfied: anyio in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.8.0)
# Requirement already satisfied: idna in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: certifi in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2024.12.14)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: jedi>=0.16 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: stack_data in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: colorama in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: exceptiongroup in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.2.2)
# Requirement already satisfied: decorator in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: pywin32>=300 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (308)
# Requirement already satisfied: platformdirs>=2.5 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: prometheus-client>=0.9 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.1)
# Requirement already satisfied: argon2-cffi>=21.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (23.1.0)
# Requirement already satisfied: overrides>=5.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: send2trash>=1.8.2 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: pywinpty>=2.0.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.14)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: websocket-client>=1.7 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: jsonschema>=4.18.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: json5>=0.9.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.1)
# Requirement already satisfied: wcwidth in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.6)
# Requirement already satisfied: sniffio>=1.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2024.10.1)
# Requirement already satisfied: attrs>=22.2.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.3.0)
# Requirement already satisfied: referencing>=0.28.4 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.1)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.22.3)
# Requirement already satisfied: rfc3339-validator in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: six>=1.5 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: executing>=1.2.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.0)
# Requirement already satisfied: uri-template in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: fqdn in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: isoduration in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.9.0.20241206)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # CONTEOS

# %% [markdown]
# ## CONTEO DE TODAS LAS VARIABLES

# %%
titanic_df.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# count   891.000000      889    891  891        891  203          889   891
# unique         NaN        3      3    3          2    7            3     2
# top            NaN        S  Third  man       True    C  Southampton    no
# freq           NaN      644    491  537        537   59          644   549
# mean     32.204208      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# std      49.693429      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# min       0.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 25%       7.910400      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 50%      14.454200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# 75%      31.000000      NaN    NaN  NaN        NaN  NaN          NaN   NaN
# max     512.329200      NaN    NaN  NaN        NaN  NaN          NaN   NaN
#
#        alone
# count    891
# unique     2
# top     True
# freq     537
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN

# %% [markdown]
# ## CONTEO DE VARIABLES NUMERICAS

# %%
titanic_df.describe(include=[np.number])
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## CONTEO DE VARIABLES CATEGORICAS

# %%
titanic_df.describe(include=object)
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
(
  titanic_df
    .astype(
        {
        'sex': 'category',
        'class' : 'category',
        'who' : 'category',
        'embark_town' : 'category'
        }
    )
).describe(include=['category',object])
# Out:
#          sex embarked  class  who deck  embark_town alive
# count    891      889    891  891  203          889   891
# unique     2        3      3    3    7            3     2
# top     male        S  Third  man    C  Southampton    no
# freq     577      644    491  537   59          644   549

# %% [markdown]
# ## GRAFICOS DE CONTEOS

# %%
(
    titanic_df
    .sex
    .value_counts()
    .plot(
        kind='bar',
        
    )
)
# Out:
# <Axes: xlabel='sex'>

# %%
(
    titanic_df
    .value_counts('embarked',sort=True)
    .reset_index(name='count')
    .pipe(
        lambda df :(
            sns.barplot(
                data=df,
                x='embarked',
                y='count',
                
            )
        )
    )
)
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %% [markdown]
# ## EJERCICIO: GRAFICAR CONTEO DE ISLAS

# %%
island_color = {
    'Torgersen': '#ff6602ff',
    'Biscoe': '#0f7175ff',
    'Dream': '#c65dc9ff'
}

# %%
(
    titanic_df
    .value_counts('class',sort=True)
    .reset_index(name='count')
    .pipe(
        lambda df :(
            sns.barplot(
                data=df,
                x='class',
                y='count',
               
            )
        )
    )
)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %% [markdown]
# ## PROPORCIONES

# %%
titanic_df['variable'] = ''

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone variable
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...      ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 16 columns]

# %%
(
    titanic_df
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                x='variable',
                hue='sex',
                multiple='fill',
                
            )
        )
    )
)

# %%
(
    titanic_df
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                x='variable',
                hue='embark_town',
                multiple='fill',
                
            )
        )
    )
)
