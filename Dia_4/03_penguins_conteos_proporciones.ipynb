# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      -------------------------------------- 294.9/294.9 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.2 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: pillow>=8 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.6)
# Requirement already satisfied: cycler>=0.10 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in d:\conocimiento adquiridos\data science _ codigo bootcamp\desarrollo_mp\bds-g3\bds-g3\virtualmodulo3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %%
penguins_df = sns.load_dataset('penguins')
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# # CONTEOS

# %% [markdown]
# ## CONTEO DE TODAS LAS VARIABLES

# %%
penguins_df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# top             NaN  Male
# freq            NaN   168
# mean    4201.754386   NaN
# std      801.954536   NaN
# min     2700.000000   NaN
# 25%     3550.000000   NaN
# 50%     4050.000000   NaN
# 75%     4750.000000   NaN
# max     6300.000000   NaN

# %% [markdown]
# ## CONTEO DE VARIABLES NUMERICAS

# %%
penguins_df.describe(include=[np.number])
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# ## CONTEO DE VARIABLES CATEGORICAS

# %%
penguins_df.describe(include=object)
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  Male
# freq       152     168   168

# %%
(
  penguins_df
    .astype(
        {
        'species': 'category',
        'island' : 'category',
        'sex' : 'category'
        }
    )
).describe(include=['category',object])
# Out:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  Male
# freq       152     168   168

# %% [markdown]
# ## GRAFICOS DE CONTEOS

# %%
(
    penguins_df
    .species
    .value_counts()
    .plot(
        kind='bar',
        color=penguin_color.values()
    )
)
# Out:
# <Axes: xlabel='species'>

# %%
(
    penguins_df
    .value_counts('species',sort=True)
    .reset_index(name='count')
    .pipe(
        lambda df :(
            sns.barplot(
                data=df,
                x='species',
                y='count',
                palette=penguin_color
            )
        )
    )
)
# Out:
# C:\Users\ingma\AppData\Local\Temp\ipykernel_20536\995176316.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# ## EJERCICIO: GRAFICAR CONTEO DE ISLAS

# %%
island_color = {
    'Torgersen': '#ff6602ff',
    'Biscoe': '#0f7175ff',
    'Dream': '#c65dc9ff'
}

# %%
(
    penguins_df
    .value_counts('island',sort=True)
    .reset_index(name='count')
    .pipe(
        lambda df :(
            sns.barplot(
                data=df,
                x='island',
                y='count',
                palette=island_color
            )
        )
    )
)
# Out:
# C:\Users\ingma\AppData\Local\Temp\ipykernel_20536\2626024619.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# ## PROPORCIONES

# %%
penguins_df['variable'] = ''

# %%
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex variable
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...      ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 8 columns]

# %%
(
    penguins_df
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                x='variable',
                hue='species',
                multiple='fill',
                palette=penguin_color
            )
        )
    )
)

# %%
(
    penguins_df
    .pipe(
        lambda df: (
            sns.displot(
                data=df,
                x='variable',
                hue='island',
                multiple='fill',
                palette=island_color
            )
        )
    )
)
