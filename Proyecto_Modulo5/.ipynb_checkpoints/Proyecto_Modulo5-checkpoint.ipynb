# %% [markdown]
# ## PROYECTO FINAL MODULO5:
# #### ENTRENAMIENTO DE MODELO DE MACHINE LEARNING PARA DETERMINAR PACIENTE QUE SUFRE ANEMIA

# %%
# !pip install pyjanitor
import janitor
# Out:
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_anemia = pd.read_csv("D:\Conocimiento Adquiridos\Data Science _ Codigo Bootcamp\Desarrollo_MP\BDS-G3\Proyecto_Modulo5\DATASET\TB_ANEMIA.csv", sep=";", encoding="utf-8")
df_anemia.head(5)
# Out:
# <>:1: DeprecationWarning: invalid escape sequence '\C'
# <>:1: DeprecationWarning: invalid escape sequence '\C'
# C:\Users\ingma\AppData\Local\Temp\ipykernel_3700\2417553001.py:1: DeprecationWarning: invalid escape sequence '\C'
#   df_anemia = pd.read_csv("D:\Conocimiento Adquiridos\Data Science _ Codigo Bootcamp\Desarrollo_MP\BDS-G3\Proyecto_Modulo5\DATASET\TB_ANEMIA.csv", sep=";", encoding="utf-8")
#    id_persona  Edad Tipo_edad Sexo  id_ubigeo  Fecha_atencion Diagnostico  \
# 0    40971314     2         A    M        NaN        20230522        D649
# 1    39270343     4         A    M     1128.0        20211122        D509
# 2    39270343     4         A    M     1128.0        20211129        D509
# 3    39155787     3         A    F     1128.0        20210527        D509
# 4    36178995     2         A    F     1299.0        20210215        D509
#
#   Tipo_Dx  id_eess
# 0       D     6203
# 1       D    10836
# 2       D    10836
# 3       D    10836
# 4       D     6079

# %%
df_anemia.isna().sum()
# Out:
# id_persona            0
# Edad                  0
# Tipo_edad             0
# Sexo                  0
# id_ubigeo         10817
# Fecha_atencion        0
# Diagnostico           0
# Tipo_Dx               0
# id_eess               0
# dtype: int64

# %%
df_anemia.shape
# Out:
# (1327924, 9)

# %%
df_anemia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1327924 entries, 0 to 1327923
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   id_persona      1327924 non-null  int64
#  1   Edad            1327924 non-null  int64
#  2   Tipo_edad       1327924 non-null  object
#  3   Sexo            1327924 non-null  object
#  4   id_ubigeo       1317107 non-null  float64
#  5   Fecha_atencion  1327924 non-null  int64
#  6   Diagnostico     1327924 non-null  object
#  7   Tipo_Dx         1327924 non-null  object
#  8   id_eess         1327924 non-null  int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 91.2+ MB

# %%
df_anemia.dropna(subset=['id_ubigeo'],inplace=True)

# %%
df_anemia.shape
# Out:
# (1317107, 9)

# %% [markdown]
# ## Tratamiento de Duplicados

# %%
df_anemia.duplicated().sum()
# Out:
# 19287

# %%
df_anemia[df_anemia.duplicated()]
# Out:
#          id_persona  Edad Tipo_edad Sexo  id_ubigeo  Fecha_atencion  \
# 329        38985611     1         A    F       26.0        20210716
# 369        38942468     1         A    M       42.0        20210627
# 610        38954543     2         A    F       42.0        20211210
# 612        38954543     2         A    F       42.0        20211110
# 827        39153550     2         A    F       26.0        20220329
# ...             ...   ...       ...  ...        ...             ...
# 1327513    35766370     2         A    F     1283.0        20210820
# 1327576    26591876     2         A    F      675.0        20211108
# 1327624    23789774     1         A    F     1288.0        20210309
# 1327878    33283345     4         A    M     1414.0        20240120
# 1327903    21185015     3         A    F      344.0        20220625
#
#         Diagnostico Tipo_Dx  id_eess
# 329            D509       D     5081
# 369            D509       D     5183
# ...

# %%
df_anemia.drop_duplicates(keep='first',inplace=True)
df_anemia.shape
# Out:
# (1297820, 9)

# %% [markdown]
# ## Analizando Variables

# %%
# Eliminamos ID_Persona
df_anemia.drop(['id_persona'],axis=1,inplace=True)
df_anemia.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Eliminamos ID_Persona
# ----> 2 df_anemia.drop(['id_persona'],axis=1,inplace=True)
#       3 df_anemia.head()
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...
